# %%
import pandas as pd

cities_in_poland = pd.read_csv("cities-in-poland.csv", sep=";")

# %% [markdown]
# Display the first 10 rows of data

# %%
cities_in_poland.head(10)
# Out:
#            City          Region      Province  Areakm2  Population
# 0   Bolesławiec   bolesławiecki  dolnośląskie    23.57       39464
# 1  Nowogrodziec   bolesławiecki  dolnośląskie    16.10        4227
# 2       Bielawa  dzierżoniowski  dolnośląskie    36.21       30987
# 3   Dzierżoniów  dzierżoniowski  dolnośląskie    20.07       34168
# 4       Niemcza  dzierżoniowski  dolnośląskie    19.81        3107
# 5      Pieszyce  dzierżoniowski  dolnośląskie    63.61        9586
# 6  Piława Górna  dzierżoniowski  dolnośląskie    20.93        6702
# 7        Głogów       głogowski  dolnośląskie    35.11       68836
# 8          Góra        górowski  dolnośląskie    13.65       12316
# 9        Wąsosz        górowski  dolnośląskie     3.24        2774

# %% [markdown]
# Display all rows of data

# %%
# pd.set_option('display.max_row', None)
# or
# cities_in_poland.head(None)

# %% [markdown]
# Display last 8 rows of data with columns: City, Province, Population

# %%
cities_in_poland.loc[:,["City", "Province", "Population"]].tail(8)
# Out:
#               City            Province  Population
# 905     Szczecinek  zachodniopomorskie       40535
# 906  Połczyn-Zdrój  zachodniopomorskie        8418
# 907        Świdwin  zachodniopomorskie       15588
# 908    Świnoujście  zachodniopomorskie       41276
# 909         Człopa  zachodniopomorskie        2345
# 910    Mirosławiec  zachodniopomorskie        3040
# 911         Tuczno  zachodniopomorskie        1956
# 912          Wałcz  zachodniopomorskie       26033

# %% [markdown]
# Calculate and add population density to the data frame (add a new column)

# %%
cities_in_poland["Density"] = cities_in_poland["Population"]/cities_in_poland["Areakm2"]

# %% [markdown]
# Display first 5 rows with columns: City, Density

# %%
cities_in_poland.loc[:,["City", "Density"]].head(5)
# Out:
#            City      Density
# 0   Bolesławiec  1674.331778
# 1  Nowogrodziec   262.546584
# 2       Bielawa   855.758078
# 3   Dzierżoniów  1702.441455
# 4       Niemcza   156.839980

# %% [markdown]
# Sort cities alphabetically and display the first 10 cities

# %%
cities_in_poland.sort_values("City").head(10)
# Out:
#                      City          Region            Province  Areakm2  \
# 91   Aleksandrów Kujawski  aleksandrowski  kujawsko-pomorskie     7.23
# 267    Aleksandrów Łódzki        zgierski             łódzkie    13.82
# 276              Alwernia     chrzanowski         małopolskie     8.88
# 328             Andrychów       wadowicki         małopolskie    10.33
# 156               Annopol       kraśnicki           lubelskie     7.73
# 503              Augustów     augustowski           podlaskie    80.90
# 214              Babimost   zielonogórski            lubuskie     3.65
# 420               Baborów      głubczycki            opolskie    11.86
# 501  Baranów Sandomierski    tarnobrzeski        podkarpackie     9.15
# 139                Barcin         żniński  kujawsko-pomorskie     3.70
#
#      Population      Density
# 91        12487  1727.109267
# 267       21224  1535.745297
# 276        3435   386.824324
# 328       20993  2032.236205
# 156        2624   339.456662
# ...

# %% [markdown]
# Display cities with at least half a million inhabitants (How many such cities are there in Poland?)

# %%
cities_in_poland.query("Population >= 500000")
# Out:
#          City              Region       Province  Areakm2  Population  \
# 75    Wrocław          Wrocław[a]   dolnośląskie   292.82      634487
# 240      Łódź             Łódź[a]        łódzkie   293.25      706004
# 290    Kraków           Kraków[a]    małopolskie   326.85      761873
# 352  Warszawa  m. st. Warszawa[a]    mazowieckie   517.24     1735442
# 807    Poznań           Poznań[a]  wielkopolskie   261.91      545680
#
#          Density
# 75   2166.815791
# 240  2407.515772
# 290  2330.956096
# 352  3355.196814
# 807  2083.463785

# %% [markdown]
# Display 10 cities with the highest population

# %%
cities_in_poland.sort_values("Population", ascending=False).head(10)
# Out:
#           City              Region            Province  Areakm2  Population  \
# 352   Warszawa  m. st. Warszawa[a]         mazowieckie   517.24     1735442
# 290     Kraków           Kraków[a]         małopolskie   326.85      761873
# 240       Łódź             Łódź[a]             łódzkie   293.25      706004
# 75     Wrocław          Wrocław[a]        dolnośląskie   292.82      634487
# 807     Poznań           Poznań[a]       wielkopolskie   261.91      545680
# 551     Gdańsk           Gdańsk[a]           pomorskie   261.96      461489
# 901   Szczecin         Szczecin[a]  zachodniopomorskie   300.55      407180
# 99   Bydgoszcz        Bydgoszcz[a]  kujawsko-pomorskie   175.98      357652
# 163     Lublin           Lublin[a]           lubelskie   147.47      341722
# 615   Katowice         Katowice[a]             śląskie   164.64      301834
#
#          Density
# 352  3355.196814
# 290  2330.956096
# 240  2407.515772
# 75   2166.815791
# 807  2083.463785
# 551  1761.677355
# ...

# %% [markdown]
# Display 10 cities with the least population

# %%
cities_in_poland.sort_values("Population").head(10)
# Out:
#                 City        Region            Province  Areakm2  Population  \
# 332      Wyśmierzyce  białobrzeski         mazowieckie    16.84         921
# 675      Działoszyce    pińczowski      świętokrzyskie     1.92         964
# 510            Suraż   białostocki           podlaskie    33.86        1009
# 890      Nowe Warpno       policki  zachodniopomorskie    24.51        1226
# 211    Szlichtyngowa     wschowski            lubuskie     1.55        1289
# 662       Skalbmierz   kazimierski      świętokrzyskie     7.13        1313
# 521       Kleszczele     hajnowski           podlaskie    46.71        1321
# 563   Krynica Morska   nowodworski           pomorskie   116.01        1335
# 137  Lubień Kujawski    włocławski  kujawsko-pomorskie     2.31        1413
# 833            Dobra       turecki       wielkopolskie     1.84        1427
#
#         Density
# 332   54.691211
# 675  502.083333
# 510   29.799173
# 890   50.020400
# 211  831.612903
# 662  184.151473
# ...

# %% [markdown]
# Display cities from the 'małopolskie' province

# %%
cities_in_poland.query("Province == 'małopolskie'")
# Out:
#                       City       Region     Province  Areakm2  Population  \
# 272                Bochnia    bocheński  małopolskie    29.87       30104
# 273           Nowy Wiśnicz    bocheński  małopolskie     4.97        2767
# 274                Brzesko      brzeski  małopolskie    11.83       17090
# 275                 Czchów      brzeski  małopolskie    14.09        2364
# 276               Alwernia  chrzanowski  małopolskie     8.88        3435
# ..                     ...          ...          ...      ...         ...
# 326                 Tarnów    Tarnów[a]  małopolskie    72.38      111376
# 327               Zakopane   tatrzański  małopolskie    84.26       27556
# 328              Andrychów    wadowicki  małopolskie    10.33       20993
# 329  Kalwaria Zebrzydowska    wadowicki  małopolskie     5.50        4603
# 330               Wadowice    wadowicki  małopolskie    10.54       19254
#
#          Density
# 272  1007.833947
# 273   556.740443
# 274  1444.632291
# ...

# %% [markdown]
# Display cities from the 'małopolskie' province and 'tarnowski' region

# %%
cities_in_poland.query("Province =='małopolskie' or Region == 'tarnowski'")
# Out:
#                       City       Region     Province  Areakm2  Population  \
# 272                Bochnia    bocheński  małopolskie    29.87       30104
# 273           Nowy Wiśnicz    bocheński  małopolskie     4.97        2767
# 274                Brzesko      brzeski  małopolskie    11.83       17090
# 275                 Czchów      brzeski  małopolskie    14.09        2364
# 276               Alwernia  chrzanowski  małopolskie     8.88        3435
# ..                     ...          ...          ...      ...         ...
# 326                 Tarnów    Tarnów[a]  małopolskie    72.38      111376
# 327               Zakopane   tatrzański  małopolskie    84.26       27556
# 328              Andrychów    wadowicki  małopolskie    10.33       20993
# 329  Kalwaria Zebrzydowska    wadowicki  małopolskie     5.50        4603
# 330               Wadowice    wadowicki  małopolskie    10.54       19254
#
#          Density
# 272  1007.833947
# 273   556.740443
# 274  1444.632291
# ...

# %% [markdown]
# Display cities from the 'małopolskie' province and 'tarnowski' region, sorted by area, starting with the largest one

# %%
cities_in_poland.query("Province =='małopolskie' or Region == 'tarnowski'").sort_values("Areakm2", ascending=False)
# Out:
#                 City        Region     Province  Areakm2  Population  \
# 290           Kraków     Kraków[a]  małopolskie   326.85      761873
# 327         Zakopane    tatrzański  małopolskie    84.26       27556
# 326           Tarnów     Tarnów[a]  małopolskie    72.38      111376
# 306          Bukowno       olkuski  małopolskie    64.59       10336
# 305        Nowy Sącz  Nowy Sącz[a]  małopolskie    57.58       83853
# ..               ...           ...          ...      ...         ...
# 273     Nowy Wiśnicz     bocheński  małopolskie     4.97        2767
# 289  Świątniki Górne     krakowski  małopolskie     4.44        2400
# 324        Zakliczyn     tarnowski  małopolskie     4.02        1661
# 288         Słomniki     krakowski  małopolskie     3.43        4402
# 286            Skała     krakowski  małopolskie     2.97        3800
#
#          Density
# 290  2330.956096
# 327   327.035367
# 326  1538.767615
# 306   160.024772
# 305  1456.286905
# ..           ...
# ...
